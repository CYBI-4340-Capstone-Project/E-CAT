# %% [markdown]
# ## Help

# %%
# %run supportFiles/train_model.py
# Out:
# Usage: supportFiles/train_model.py <MAX_NUM_FILES> <FEATURE_SET> <PCAP_SOURCE> ["KEEP"] ["SCAN_ALL" (has precedence)] ["SCAN_ONLY"]
# Datasets available are :
#  {0: 'AB-TRAP', 1: 'NB15', 2: 'CIC-IDS', 3: 'ToN-IoT', 4: 'BoT-IoT', 5: 'internet'}

# %%
TYPE_OF_TEST = "\"KEEP\" \"SCAN_ONLY\" \"oversampling\"" #\"undersampling\"" #"SCAN_ALL"
MAX_NUM_FILES = 96
CIC_FEATURES = 1

# %% [markdown]
# # UPDATES
# The cell above me is the defualt one to run train_model.py
# The cell below is for combine2.py
# just changed the oversampling to ADASYN
#
# manually, in combine2.py at the bottom I input
# Cycle through datasets 1, 2, 3, 4
#     for pcapTypeNum in [4]:
#  so it can just run through all datasets 1-4 and not just 1 dataset. except pc crashed by ToN
#
# ### To reduce clutter I removed the outputs from the original cells. Please refer to the original github repo for the original outputs

# %%
TYPE_OF_TEST = "\"KEEP\" \"SCAN_ONLY\" \"ADASYN\"" #\"SMOTE_Tomek\"" #"doesn't really matter since we are using all attacks, not just reconaissance ones"
MAX_NUM_FILES = 96
CIC_FEATURES = 1

# %%
# %run combine2.py $MAX_NUM_FILES $CIC_FEATURES 1 $TYPE_OF_TEST
# Out:
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# No Overwrite selected. Skipping ML for existing joblib files
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# Preparing for training...
# pcapTypeNum:  1
# maxNumFiles:  96
# datasetTypeNum:  1
# scanOnly:  True
# scan:  True
# Loading data set from existing file: NB15_CIC.csv
# Reading zero variance features from ./ML-output/zeroVarNB15_CIC.txt
# Zero variance features read from ./ML-output/zeroVarNB15_CIC.txt
# Initial class distribution in y:
#  Label
# benign            4802644
# Exploits            50329
# Fuzzers             33986
# Reconnaissance      18667
# Generic              7368
# DoS                  6996
# Shellcode            2259
# Analysis              933
# Backdoor              649
# Worms                 317
# Backdoors             105
# Name: count, dtype: int64
# Class distribution in y after transformation:
#  Label
# 0    4802644
# 1     121609
# ...

# %%
# %run combine2.py $MAX_NUM_FILES $CIC_FEATURES 2 $TYPE_OF_TEST
# Out:
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# No Overwrite selected. Skipping ML for existing joblib files
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# Preparing for training...
# pcapTypeNum:  2
# maxNumFiles:  96
# datasetTypeNum:  1
# scanOnly:  True
# scan:  True
# Loading data set from existing file: CIC-IDS_CIC.csv
# Reading zero variance features from ./ML-output/zeroVarCIC-IDS_CIC.txt
# Zero variance features read from ./ML-output/zeroVarCIC-IDS_CIC.txt
# Initial class distribution in y:
#  Label
# BENIGN                        2271122
# DoS Hulk                       230123
# PortScan                       158804
# DDoS                           128025
# DoS GoldenEye                   10293
# FTP-Patator                      7935
# SSH-Patator                      5897
# DoS slowloris                    5796
# DoS Slowhttptest                 5499
# Bot                              1956
# ...

# %% [markdown]
# ### TRAIN ALL

# %% [markdown]
# ## Train AB-TRAP data set models for scanning attack detection

# %% [markdown]
# ## Train internet AB-TRAP data set models for scanning attack detection

# %% [markdown]
# ## Train UNSW-NB15 data set models for scanning attack detection

# %% [markdown]
# ## Train CIC-IDS data set models for scanning attack detection

# %% [markdown]
# ## Train ToN-IoT data set models for scanning attack detection

# %%
# %run combine2.py $MAX_NUM_FILES $CIC_FEATURES 3 $TYPE_OF_TEST
# Out:
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# ToN-IoT and BoT-IoT only available in CIC dataset type
# No Overwrite selected. Skipping ML for existing joblib files
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# Preparing for training...
# pcapTypeNum:  3
# maxNumFiles:  96
# datasetTypeNum:  1
# scanOnly:  True
# scan:  True
# Loading data set from existing file: ToN-IoT_CIC.csv
# Reading zero variance features from ./ML-output/zeroVarToN-IoT_CIC.txt
# Zero variance features read from ./ML-output/zeroVarToN-IoT_CIC.txt
# Initial class distribution in y:
#  Label
# Benign        2514059
# xss           2149308
# password       340208
# injection      277696
# scanning        36205
# backdoor        27145
# ransomware       5098
# mitm              517
# ddos              202
# dos               145
# Name: count, dtype: int64
# Class distribution in y after transformation:
#  Label
# 1    2836524
# 0    2514059
# ...

# %% [markdown]
# ## Train BoT-IoT data set models for scanning attack detection

# %%
# %run combine2.py $MAX_NUM_FILES $CIC_FEATURES 4 $TYPE_OF_TEST
# Out:
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# ToN-IoT and BoT-IoT only available in CIC dataset type
# No Overwrite selected. Skipping ML for existing joblib files
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# Preparing for training...
# pcapTypeNum:  4
# maxNumFiles:  96
# datasetTypeNum:  1
# scanOnly:  True
# scan:  True
# Loading data set from existing file: BoT-IoT_CIC.csv
# Reading zero variance features from ./ML-output/zeroVarBoT-IoT_CIC.txt
# Zero variance features read from ./ML-output/zeroVarBoT-IoT_CIC.txt
# Initial class distribution in y:
#  Label
# DDoS              4913860
# DoS               4909359
# Reconnaissance    3513408
# Benign              89234
# Theft                1701
# benign                  1
# Name: count, dtype: int64
# Class distribution in y after transformation:
#  Label
# 1    13338328
# 0       89235
# Name: count, dtype: int64
# Columns in X:
# ...

# %% [markdown]
# ## The ones missing

# %%
# %pip install -U imbalanced-learn
# Out:
# ...
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 0.24.1
#     Uninstalling scikit-learn-0.24.1:
#       Successfully uninstalled scikit-learn-0.24.1
# ...
# Note: you may need to restart the kernel to use updated packages.
