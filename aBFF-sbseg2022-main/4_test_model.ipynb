# %% [markdown]
# ## Help

# %%
# %run supportFiles/evaluate.py
# Out:
# Usage: supportFiles/evaluate.py <MAX_NUM_FILES> <FEATURE_SET> <PCAP_SOURCE> ["KEEP"] ["SCAN_ALL"] ["SCAN_ONLY"]
# Datasets available are :
#  {0: 'AB-TRAP', 1: 'NB15', 2: 'CIC-IDS', 3: 'ToN-IoT', 4: 'BoT-IoT', 5: 'internet'}

# %% [markdown]
# ### Test conditions

# %%
TYPE_OF_TEST = "\"KEEP\" \"SCAN_ONLY\" \"oversampling\"" # \"oversampling\" \"SCAN_ALL\"
MAX_NUM_FILES = 96
CIC_FEATURES = 1
METHOD = "evaluateBinary.py" #"evaluate.py"

# %% [markdown]
# ### RUN ALL

# %%
#%run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 0 $TYPE_OF_TEST
# %run $METHOD $MAX_NUM_FILES $CIC_FEATURES 1 $TYPE_OF_TEST
# %run $METHOD $MAX_NUM_FILES $CIC_FEATURES 2 $TYPE_OF_TEST
# %run $METHOD $MAX_NUM_FILES $CIC_FEATURES 3 $TYPE_OF_TEST
# %run $METHOD $MAX_NUM_FILES $CIC_FEATURES 4 $TYPE_OF_TEST
#%run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 5 $TYPE_OF_TEST
# Out:
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# Using models with oversampled minority class.
# loading models from SCAN_NB15_CIC_os
# Models fetched: ['SCAN_NB15_CIC_os_DT.joblib', 'SCAN_NB15_CIC_os_LR.joblib', 'SCAN_NB15_CIC_os_MLP.joblib', 'SCAN_NB15_CIC_os_NB.joblib', 'SCAN_NB15_CIC_os_SVM.joblib', 'SCAN_NB15_CIC_os_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# XGB
# F1-score file for SCAN_NB15_CIC_os data set not found. Creating..
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# THIS IS loadAndSet
# ...

# %%
# %run $METHOD $MAX_NUM_FILES $CIC_FEATURES 1 $TYPE_OF_TEST
# Out:
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# Using models with oversampled minority class.
# loading models from SCAN_NB15_CIC_os
# Models fetched: ['SCAN_NB15_CIC_os_DT.joblib', 'SCAN_NB15_CIC_os_LR.joblib', 'SCAN_NB15_CIC_os_MLP.joblib', 'SCAN_NB15_CIC_os_NB.joblib', 'SCAN_NB15_CIC_os_SVM.joblib', 'SCAN_NB15_CIC_os_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# XGB
# Found F1-score file for SCAN_NB15_CIC_os data set
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
# THIS IS loadAndSet
# ...

# %% [markdown]
# (tf) C:\Users\Daniel\Documents\GitHub\E-CAT\aBFF-sbseg2022-main\supportFiles>python evaluateBinary.py 96 1 1 "KEEP" "SCAN_ONLY" "oversampling"
#
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
#
# No Overwrite selected. Skipping data sets already tested
#
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
#
# Using models with oversampled minority class.
#
# loading models from SCAN_NB15_CIC_os
#
# Models fetched: ['SCAN_NB15_CIC_os_DT.joblib', 'SCAN_NB15_CIC_os_LR.joblib', 'SCAN_NB15_CIC_os_MLP.joblib', 'SCAN_NB15_CIC_os_NB.joblib', 'SCAN_NB15_CIC_os_SVM.joblib', 'SCAN_NB15_CIC_os_XGB.joblib']
#
# DT's index of best performance: 5
#
# LR's index of best performance: 0
#
# MLP's index of best performance: 0
#
# NB's index of best performance: 0
#
# SVM's index of best performance: 0
#
# XGB's index of best performance: 0
#
# XGB
#
# Found F1-score file for SCAN_NB15_CIC_os data set
#
# DSName:  SCAN_CIC-IDS_CIC
#
# zeroVarType:  1
#
# Reading feature list from ./ML-output/features_NB15_CIC.txt
#
# Reading zero variance features from ./ML-output/zeroVarNB15_CIC.txt
#
# Zero variance features read from ./ML-output/zeroVarNB15_CIC.txt
#
# finalfilepath:  ./dataset/final/CIC-IDS_CIC.csv
#
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'syn_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_pkts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min', 'Label']
#
# Loading data set from existing file: SCAN_CIC-IDS_CIC.csv
# 2025-03-11 17:59:32
# Evaluating SCAN_NB15_CIC_os's ML models on SCAN_CIC-IDS_CIC data set
#
# 2025-03-11 17:59:34
# F1-score for DT: TN = 2221676, FP = 49446, FN = 157353, TP = 1451
#
# 2025-03-11 17:59:36
# F1-score for LR: TN = 2120620, FP = 150502, FN = 149759, TP = 9045
#
# 2025-03-11 17:59:38
# F1-score for MLP: TN = 2152954, FP = 118168, FN = 158700, TP = 104
#
# 2025-03-11 17:59:43
# F1-score for NB: TN = 2225961, FP = 45161, FN = 158473, TP = 331
#
# 2025-03-11 17:59:44
# F1-score for SVM: TN = 2122462, FP = 148660, FN = 144960, TP = 13844
#
# 2025-03-11 17:59:47
# F1-score for XGB: TN = 2236454, FP = 34668, FN = 157805, TP = 999
#
# THIS IS loadAndSet
# DSName:  SCAN_ToN-IoT_CIC
# zeroVarType:  1
# Reading feature list from ./ML-output/features_NB15_CIC.txt
# Reading zero variance features from ./ML-output/zeroVarNB15_CIC.txt
# Zero variance features read from ./ML-output/zeroVarNB15_CIC.txt
# finalfilepath:  ./dataset/final/ToN-IoT_CIC.csv
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'syn_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_pkts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_ToN-IoT_CIC.csv
# 2025-03-11 18:00:26
# Evaluating SCAN_NB15_CIC_os's ML models on SCAN_ToN-IoT_CIC data set
#
# 2025-03-11 18:00:28
# F1-score for DT: TN = 2413579, FP = 100480, FN = 30903, TP = 5302
#
# 2025-03-11 18:00:30
# F1-score for LR: TN = 371509, FP = 2142550, FN = 2974, TP = 33231
#
# 2025-03-11 18:00:32
# F1-score for MLP: TN = 0, FP = 2514059, FN = 0, TP = 36205
#
# 2025-03-11 18:00:37
# F1-score for NB: TN = 196, FP = 2513863, FN = 0, TP = 36205
#
# 2025-03-11 18:00:39
# F1-score for SVM: TN = 371509, FP = 2142550, FN = 2974, TP = 33231
#
# 2025-03-11 18:00:41
# F1-score for XGB: TN = 2430214, FP = 83845, FN = 30774, TP = 5431
#
# THIS IS loadAndSet
# DSName:  SCAN_BoT-IoT_CIC
# zeroVarType:  1
# Reading feature list from ./ML-output/features_NB15_CIC.txt
# Reading zero variance features from ./ML-output/zeroVarNB15_CIC.txt
# Zero variance features read from ./ML-output/zeroVarNB15_CIC.txt
# finalfilepath:  ./dataset/final/BoT-IoT_CIC.csv
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'syn_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_pkts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_BoT-IoT_CIC.csv
# 2025-03-11 18:03:21
# Evaluating SCAN_NB15_CIC_os's ML models on SCAN_BoT-IoT_CIC data set
#
# 2025-03-11 18:03:24
# F1-score for DT: TN = 36999, FP = 52235, FN = 1218867, TP = 2294541
#
# 2025-03-11 18:03:26
# F1-score for LR: TN = 82584, FP = 6650, FN = 3430912, TP = 82496
#
# 2025-03-11 18:03:38
# F1-score for MLP: TN = 83525, FP = 5709, FN = 3451554, TP = 61854
#
# 2025-03-11 18:03:44
# F1-score for NB: TN = 89182, FP = 52, FN = 3499986, TP = 13422
#
# 2025-03-11 18:03:47
# F1-score for SVM: TN = 69732, FP = 19502, FN = 3028330, TP = 485078
#
# 2025-03-11 18:03:50
# F1-score for XGB: TN = 87270, FP = 1964, FN = 3444191, TP = 69217

# %%
# %run $METHOD $MAX_NUM_FILES $CIC_FEATURES 2 $TYPE_OF_TEST

# %% [markdown]
# (tf) C:\Users\Daniel\Documents\GitHub\E-CAT\aBFF-sbseg2022-main\supportFiles>python evaluateBinary.py 96 1 2 "KEEP" "SCAN_ONLY" "oversampling"
#
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
#
# No Overwrite selected. Skipping data sets already tested
#
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
#
# Using models with oversampled minority class.
#
# loading models from SCAN_CIC-IDS_CIC_os
#
# Models fetched: ['SCAN_CIC-IDS_CIC_os_DT.joblib', 'SCAN_CIC-IDS_CIC_os_LR.joblib', 'SCAN_CIC-IDS_CIC_os_MLP.joblib', 'SCAN_CIC-IDS_CIC_os_NB.joblib', 'SCAN_CIC-IDS_CIC_os_SVM.joblib', 'SCAN_CIC-IDS_CIC_os_XGB.joblib']
#
# DT's index of best performance: 11
#
# LR's index of best performance: 0
#
# MLP's index of best performance: 0
#
# NB's index of best performance: 0
#
# SVM's index of best performance: 0
#
# XGB's index of best performance: 0
#
# XGB
#
# F1-score file for SCAN_CIC-IDS_CIC_os data set not found. Creating..
#
# DSName:  SCAN_NB15_CIC
#
# zeroVarType:  2
#
# Reading feature list from ./ML-output/features_CIC-IDS_CIC.txt
#
# Reading zero variance features from ./ML-output/zeroVarCIC-IDS_CIC.txt
#
# Zero variance features read from ./ML-output/zeroVarCIC-IDS_CIC.txt
#
# finalfilepath:  ./dataset/final/NB15_CIC.csv
#
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_urg_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'fin_flag_cnt', 'syn_flag_cnt', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'cwe_flag_count', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_pkts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_NB15_CIC.csv
# 2025-03-11 18:18:48
# Evaluating SCAN_CIC-IDS_CIC_os's ML models on SCAN_NB15_CIC data set
#
# 2025-03-11 18:18:48
# F1-score for DT: TN = 0, FP = 0, FN = 18665, TP = 2
#
# 2025-03-11 18:18:48
# F1-score for LR: TN = 0, FP = 0, FN = 18586, TP = 81
#
# 2025-03-11 18:18:48
# F1-score for MLP: TN = 0, FP = 0, FN = 18662, TP = 5
#
# 2025-03-11 18:18:48
# F1-score for NB: TN = 0, FP = 0, FN = 18660, TP = 7
#
# 2025-03-11 18:18:48
# F1-score for SVM: TN = 0, FP = 0, FN = 18596, TP = 71
#
# 2025-03-11 18:18:48
# F1-score for XGB: TN = 0, FP = 0, FN = 18667, TP = 0
#
# THIS IS loadAndSet
# DSName:  SCAN_ToN-IoT_CIC
# zeroVarType:  2
# Reading feature list from ./ML-output/features_CIC-IDS_CIC.txt
# Reading zero variance features from ./ML-output/zeroVarCIC-IDS_CIC.txt
# Zero variance features read from ./ML-output/zeroVarCIC-IDS_CIC.txt
# finalfilepath:  ./dataset/final/ToN-IoT_CIC.csv
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_urg_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'fin_flag_cnt', 'syn_flag_cnt', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'cwe_flag_count', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_pkts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_ToN-IoT_CIC.csv
# 2025-03-11 18:19:23
# Evaluating SCAN_CIC-IDS_CIC_os's ML models on SCAN_ToN-IoT_CIC data set
#
# 2025-03-11 18:19:25
# F1-score for DT: TN = 2501684, FP = 12375, FN = 29637, TP = 6568
#
# 2025-03-11 18:19:27
# F1-score for LR: TN = 2514059, FP = 0, FN = 36205, TP = 0
#
# 2025-03-11 18:19:29
# F1-score for MLP: TN = 0, FP = 2514059, FN = 0, TP = 36205
#
# 2025-03-11 18:19:33
# F1-score for NB: TN = 2514059, FP = 0, FN = 36205, TP = 0
#
# 2025-03-11 18:19:35
# F1-score for SVM: TN = 2514059, FP = 0, FN = 36205, TP = 0
#
# 2025-03-11 18:19:37
# F1-score for XGB: TN = 2512909, FP = 1150, FN = 35957, TP = 248
#
# THIS IS loadAndSet
# DSName:  SCAN_BoT-IoT_CIC
# zeroVarType:  2
# Reading feature list from ./ML-output/features_CIC-IDS_CIC.txt
# Reading zero variance features from ./ML-output/zeroVarCIC-IDS_CIC.txt
# Zero variance features read from ./ML-output/zeroVarCIC-IDS_CIC.txt
# finalfilepath:  ./dataset/final/BoT-IoT_CIC.csv
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_urg_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'fin_flag_cnt', 'syn_flag_cnt', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'cwe_flag_count', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_pkts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_BoT-IoT_CIC.csv
# 2025-03-11 18:22:06
# Evaluating SCAN_CIC-IDS_CIC_os's ML models on SCAN_BoT-IoT_CIC data set
#
# 2025-03-11 18:22:09
# F1-score for DT: TN = 89067, FP = 167, FN = 3513086, TP = 322
#
# 2025-03-11 18:22:11
# F1-score for LR: TN = 83982, FP = 5252, FN = 3494554, TP = 18854
#
# 2025-03-11 18:22:22
# F1-score for MLP: TN = 80776, FP = 8458, FN = 3465976, TP = 47432
#
# 2025-03-11 18:22:29
# F1-score for NB: TN = 85031, FP = 4203, FN = 3494223, TP = 19185
#
# 2025-03-11 18:22:31
# F1-score for SVM: TN = 80443, FP = 8791, FN = 3484181, TP = 29227
#
# 2025-03-11 18:22:36
# F1-score for XGB: TN = 89223, FP = 11, FN = 3513255, TP = 153

# %%
# %run $METHOD $MAX_NUM_FILES $CIC_FEATURES 3 $TYPE_OF_TEST

# %% [markdown]
# (tf) C:\Users\Daniel\Documents\GitHub\E-CAT\aBFF-sbseg2022-main\supportFiles>python evaluateBinary.py 96 1 3 "KEEP" "SCAN_ONLY" "oversampling"
#
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
#
# ToN-IoT and BoT-IoT only available in CIC dataset type
#
# No Overwrite selected. Skipping data sets already tested
#
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
#
# Using models with oversampled minority class.
#
# loading models from SCAN_ToN-IoT_CIC_os
#
# Models fetched: ['SCAN_ToN-IoT_CIC_os_DT.joblib', 'SCAN_ToN-IoT_CIC_os_LR.joblib', 'SCAN_ToN-IoT_CIC_os_MLP.joblib', 'SCAN_ToN-IoT_CIC_os_NB.joblib', 'SCAN_ToN-IoT_CIC_os_SVM.joblib', 'SCAN_ToN-IoT_CIC_os_XGB.joblib']
#
# DT's index of best performance: 5
#
# LR's index of best performance: 0
#
# MLP's index of best performance: 0
#
# NB's index of best performance: 0
#
# SVM's index of best performance: 0
#
# XGB's index of best performance: 0
#
# XGB
#
# F1-score file for SCAN_ToN-IoT_CIC_os data set not found. Creating..
#
# DSName:  SCAN_NB15_CIC
#
# zeroVarType:  3
#
# Reading feature list from ./ML-output/features_ToN-IoT_CIC.txt
#
# Reading zero variance features from ./ML-output/zeroVarToN-IoT_CIC.txt
#
# Zero variance features read from ./ML-output/zeroVarToN-IoT_CIC.txt
#
# finalfilepath:  ./dataset/final/NB15_CIC.csv
#
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'fin_flag_cnt', 'syn_flag_cnt', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'cwe_flag_count', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'bwd_byts_b_avg', 'bwd_pkts_b_avg', 'bwd_blk_rate_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_NB15_CIC.csv
# 2025-03-11 18:24:05
# Evaluating SCAN_ToN-IoT_CIC_os's ML models on SCAN_NB15_CIC data set
#
# 2025-03-11 18:24:05
# F1-score for DT: TN = 0, FP = 0, FN = 14244, TP = 4423
#
# 2025-03-11 18:24:05
# F1-score for LR: TN = 0, FP = 0, FN = 16935, TP = 1732
#
# 2025-03-11 18:24:05
# F1-score for MLP: TN = 0, FP = 0, FN = 17320, TP = 1347
#
# 2025-03-11 18:24:05
# F1-score for NB: TN = 0, FP = 0, FN = 16941, TP = 1726
#
# 2025-03-11 18:24:05
# F1-score for SVM: TN = 0, FP = 0, FN = 18661, TP = 6
#
# 2025-03-11 18:24:05
# F1-score for XGB: TN = 0, FP = 0, FN = 2612, TP = 16055
#
# THIS IS loadAndSet
# DSName:  SCAN_CIC-IDS_CIC
# zeroVarType:  3
# Reading feature list from ./ML-output/features_ToN-IoT_CIC.txt
# Reading zero variance features from ./ML-output/zeroVarToN-IoT_CIC.txt
# Zero variance features read from ./ML-output/zeroVarToN-IoT_CIC.txt
# finalfilepath:  ./dataset/final/CIC-IDS_CIC.csv
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'fin_flag_cnt', 'syn_flag_cnt', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'cwe_flag_count', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'bwd_byts_b_avg', 'bwd_pkts_b_avg', 'bwd_blk_rate_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_CIC-IDS_CIC.csv
# 2025-03-11 18:24:25
# Evaluating SCAN_ToN-IoT_CIC_os's ML models on SCAN_CIC-IDS_CIC data set
#
# 2025-03-11 18:24:27
# F1-score for DT: TN = 1570963, FP = 700159, FN = 156487, TP = 2317
#
# 2025-03-11 18:24:29
# F1-score for LR: TN = 2238781, FP = 32341, FN = 157054, TP = 1750
#
# 2025-03-11 18:24:31
# F1-score for MLP: TN = 2252096, FP = 19026, FN = 158581, TP = 223
#
# 2025-03-11 18:24:35
# F1-score for NB: TN = 1967412, FP = 303710, FN = 151289, TP = 7515
#
# 2025-03-11 18:24:37
# F1-score for SVM: TN = 2238437, FP = 32685, FN = 155107, TP = 3697
#
# 2025-03-11 18:24:39
# F1-score for XGB: TN = 1080912, FP = 1190210, FN = 132695, TP = 26109
#
# THIS IS loadAndSet
# DSName:  SCAN_BoT-IoT_CIC
# zeroVarType:  3
# Reading feature list from ./ML-output/features_ToN-IoT_CIC.txt
# Reading zero variance features from ./ML-output/zeroVarToN-IoT_CIC.txt
# Zero variance features read from ./ML-output/zeroVarToN-IoT_CIC.txt
# finalfilepath:  ./dataset/final/BoT-IoT_CIC.csv
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'fwd_psh_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'fin_flag_cnt', 'syn_flag_cnt', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'cwe_flag_count', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'bwd_byts_b_avg', 'bwd_pkts_b_avg', 'bwd_blk_rate_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'fwd_seg_size_min', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_BoT-IoT_CIC.csv
# 2025-03-11 18:27:15
# Evaluating SCAN_ToN-IoT_CIC_os's ML models on SCAN_BoT-IoT_CIC data set
#
# 2025-03-11 18:27:19
# F1-score for DT: TN = 56360, FP = 32874, FN = 2393085, TP = 1120323
#
# 2025-03-11 18:27:21
# F1-score for LR: TN = 56635, FP = 32599, FN = 3291331, TP = 222077
#
# 2025-03-11 18:27:43
# F1-score for MLP: TN = 88354, FP = 880, FN = 3512189, TP = 1219
#
# 2025-03-11 18:27:49
# F1-score for NB: TN = 72421, FP = 16813, FN = 3365190, TP = 148218
#
# 2025-03-11 18:27:51
# F1-score for SVM: TN = 56394, FP = 32840, FN = 3300429, TP = 212979
#
# 2025-03-11 18:27:58
# F1-score for XGB: TN = 76758, FP = 12476, FN = 2027007, TP = 1486401

# %%
# %run $METHOD $MAX_NUM_FILES $CIC_FEATURES 4 $TYPE_OF_TEST

# %% [markdown]
# (tf) C:\Users\Daniel\Documents\GitHub\E-CAT\aBFF-sbseg2022-main\supportFiles>python evaluateBinary.py 96 1 4 "KEEP" "SCAN_ONLY" "oversampling"
#
# pcapType.keys(): dict_keys([0, 1, 2, 3, 4, 5])
#
# ToN-IoT and BoT-IoT only available in CIC dataset type
#
# No Overwrite selected. Skipping data sets already tested
#
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
#
# Using models with oversampled minority class.
#
# loading models from SCAN_BoT-IoT_CIC_os
#
# Models fetched: ['SCAN_BoT-IoT_CIC_os_DT.joblib', 'SCAN_BoT-IoT_CIC_os_LR.joblib', 'SCAN_BoT-IoT_CIC_os_MLP.joblib', 'SCAN_BoT-IoT_CIC_os_NB.joblib', 'SCAN_BoT-IoT_CIC_os_SVM.joblib', 'SCAN_BoT-IoT_CIC_os_XGB.joblib']
#
# DT's index of best performance: 5
#
# LR's index of best performance: 0
#
# MLP's index of best performance: 0
#
# NB's index of best performance: 0
#
# SVM's index of best performance: 0
#
# XGB's index of best performance: 0
#
# DT
#
# F1-score file for SCAN_BoT-IoT_CIC_os data set not found. Creating..
#
# DSName:  SCAN_NB15_CIC
#
# zeroVarType:  4
#
# Reading feature list from ./ML-output/features_BoT-IoT_CIC.txt
#
# Reading zero variance features from ./ML-output/zeroVarBoT-IoT_CIC.txt
#
# Zero variance features read from ./ML-output/zeroVarBoT-IoT_CIC.txt
#
# finalfilepath:  ./dataset/final/NB15_CIC.csv
#
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'bwd_psh_flags', 'bwd_urg_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'fin_flag_cnt', 'syn_flag_cnt', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'cwe_flag_count', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_pkts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_NB15_CIC.csv
# 2025-03-11 18:29:45
# Evaluating SCAN_BoT-IoT_CIC_os's ML models on SCAN_NB15_CIC data set
#
# 2025-03-11 18:29:45
# F1-score for DT: TN = 0, FP = 0, FN = 12866, TP = 5801
#
# 2025-03-11 18:29:45
# F1-score for LR: TN = 0, FP = 0, FN = 10344, TP = 8323
#
# 2025-03-11 18:29:46
# F1-score for MLP: TN = 0, FP = 0, FN = 11691, TP = 6976
#
# 2025-03-11 18:29:46
# F1-score for NB: TN = 0, FP = 0, FN = 11762, TP = 6905
#
# 2025-03-11 18:29:46
# F1-score for SVM: TN = 0, FP = 0, FN = 11343, TP = 7324
#
# 2025-03-11 18:29:46
# F1-score for XGB: TN = 0, FP = 0, FN = 13764, TP = 4903
#
# THIS IS loadAndSet
# DSName:  SCAN_CIC-IDS_CIC
# zeroVarType:  4
# Reading feature list from ./ML-output/features_BoT-IoT_CIC.txt
# Reading zero variance features from ./ML-output/zeroVarBoT-IoT_CIC.txt
# Zero variance features read from ./ML-output/zeroVarBoT-IoT_CIC.txt
# finalfilepath:  ./dataset/final/CIC-IDS_CIC.csv
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'bwd_psh_flags', 'bwd_urg_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'fin_flag_cnt', 'syn_flag_cnt', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'cwe_flag_count', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_pkts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_CIC-IDS_CIC.csv
# 2025-03-11 18:30:07
# Evaluating SCAN_BoT-IoT_CIC_os's ML models on SCAN_CIC-IDS_CIC data set
#
# 2025-03-11 18:30:09
# F1-score for DT: TN = 1771507, FP = 499615, FN = 136587, TP = 22217
#
# 2025-03-11 18:30:10
# F1-score for LR: TN = 1556755, FP = 714367, FN = 146522, TP = 12282
#
# 2025-03-11 18:30:12
# F1-score for MLP: TN = 1781346, FP = 489776, FN = 155700, TP = 3104
#
# 2025-03-11 18:30:17
# F1-score for NB: TN = 1768373, FP = 502749, FN = 158553, TP = 251
#
# 2025-03-11 18:30:18
# F1-score for SVM: TN = 1622446, FP = 648676, FN = 147120, TP = 11684
#
# 2025-03-11 18:30:21
# F1-score for XGB: TN = 2116507, FP = 154615, FN = 103396, TP = 55408
#
# THIS IS loadAndSet
# DSName:  SCAN_ToN-IoT_CIC
# zeroVarType:  4
# Reading feature list from ./ML-output/features_BoT-IoT_CIC.txt
# Reading zero variance features from ./ML-output/zeroVarBoT-IoT_CIC.txt
# Zero variance features read from ./ML-output/zeroVarBoT-IoT_CIC.txt
# finalfilepath:  ./dataset/final/ToN-IoT_CIC.csv
# features:  ['dst_port', 'protocol', 'flow_duration', 'tot_fwd_pkts', 'tot_bwd_pkts', 'totlen_fwd_pkts', 'totlen_bwd_pkts', 'fwd_pkt_len_max', 'fwd_pkt_len_min', 'fwd_pkt_len_mean', 'fwd_pkt_len_std', 'bwd_pkt_len_max', 'bwd_pkt_len_min', 'bwd_pkt_len_mean', 'bwd_pkt_len_std', 'flow_byts_s', 'flow_pkts_s', 'flow_iat_mean', 'flow_iat_std', 'flow_iat_max', 'flow_iat_min', 'fwd_iat_tot', 'fwd_iat_mean', 'fwd_iat_std', 'fwd_iat_max', 'fwd_iat_min', 'bwd_iat_tot', 'bwd_iat_mean', 'bwd_iat_std', 'bwd_iat_max', 'bwd_iat_min', 'bwd_psh_flags', 'bwd_urg_flags', 'fwd_header_len', 'bwd_header_len', 'fwd_pkts_s', 'bwd_pkts_s', 'pkt_len_min', 'pkt_len_max', 'pkt_len_mean', 'pkt_len_std', 'pkt_len_var', 'fin_flag_cnt', 'syn_flag_cnt', 'rst_flag_cnt', 'psh_flag_cnt', 'ack_flag_cnt', 'urg_flag_cnt', 'cwe_flag_count', 'ece_flag_cnt', 'down_up_ratio', 'pkt_size_avg', 'fwd_seg_size_avg', 'bwd_seg_size_avg', 'subflow_fwd_pkts', 'subflow_fwd_byts', 'subflow_bwd_pkts', 'subflow_bwd_byts', 'init_fwd_win_byts', 'init_bwd_win_byts', 'fwd_act_data_pkts', 'active_mean', 'active_std', 'active_max', 'active_min', 'idle_mean', 'idle_std', 'idle_max', 'idle_min', 'Label']
# Loading data set from existing file: SCAN_ToN-IoT_CIC.csv
# 2025-03-11 18:30:57
# Evaluating SCAN_BoT-IoT_CIC_os's ML models on SCAN_ToN-IoT_CIC data set
#
# 2025-03-11 18:30:59
# F1-score for DT: TN = 2492229, FP = 21830, FN = 33835, TP = 2370
#
# 2025-03-11 18:31:01
# F1-score for LR: TN = 2142550, FP = 371509, FN = 33231, TP = 2974
#
# 2025-03-11 18:31:03
# F1-score for MLP: TN = 0, FP = 2514059, FN = 0, TP = 36205
#
# 2025-03-11 18:31:07
# F1-score for NB: TN = 0, FP = 2514059, FN = 0, TP = 36205
#
# 2025-03-11 18:31:09
# F1-score for SVM: TN = 2514027, FP = 32, FN = 36205, TP = 0
#
# 2025-03-11 18:31:12
# F1-score for XGB: TN = 2335225, FP = 178834, FN = 11040, TP = 25165

# %%
TYPE_OF_TEST = "\"KEEP\" \"SCAN_ALL\" \"oversampling\"" # \"oversampling\" \"SCAN_ALL\"
MAX_NUM_FILES = 96
CIC_FEATURES = 1
METHOD = "evaluateBinary.py" #"evaluate.py"

# %% [markdown]
# # Run Individually

# %% [markdown]
# ## Test AB-TRAP data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 0 $TYPE_OF_TEST
# Out:
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_AB-TRAP_CIC
# Models fetched: ['SCAN_AB-TRAP_CIC_DT.joblib', 'SCAN_AB-TRAP_CIC_LR.joblib', 'SCAN_AB-TRAP_CIC_MLP.joblib', 'SCAN_AB-TRAP_CIC_NB.joblib', 'SCAN_AB-TRAP_CIC_SVM.joblib', 'SCAN_AB-TRAP_CIC_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# DT
# F1-score file for SCAN_AB-TRAP_CIC data set not found. Creating..
# reading file:
# Loading data set from existing file: SCAN_NB15_CIC.csv
# 2022-01-14 15:40:38
# Evaluating SCAN_AB-TRAP_CIC's ML models on SCAN_NB15_CIC data set
#
# DT's scoreA = 0.554954954954955, scoreB = 0.0
# 2022-01-14 15:40:38
# F1-score for DT: Attack 0.554954954954955, Benign 0.0
#
# ...

# %% [markdown]
# ## Test UNSW-NB15 data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 1 $TYPE_OF_TEST
# Out:
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_NB15_CIC
# Models fetched: ['SCAN_NB15_CIC_DT.joblib', 'SCAN_NB15_CIC_LR.joblib', 'SCAN_NB15_CIC_MLP.joblib', 'SCAN_NB15_CIC_NB.joblib', 'SCAN_NB15_CIC_SVM.joblib', 'SCAN_NB15_CIC_XGB.joblib']
# DT's index of best performance: 10
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# DT
# Found F1-score file for SCAN_NB15_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-12 15:33:45
# Evaluating SCAN_NB15_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-12 15:34:04
# F1-score for DT: 0.0
#
# LR's score = 0.0
# 2022-01-12 15:34:19
# F1-score for LR: 0.0
#
# MLP's score = 0.0
# 2022-01-12 15:34:29
# ...

# %% [markdown]
# ## Test CIC-IDS data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 2 $TYPE_OF_TEST
# Out:
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_CIC-IDS_CIC
# Models fetched: ['SCAN_CIC-IDS_CIC_DT.joblib', 'SCAN_CIC-IDS_CIC_LR.joblib', 'SCAN_CIC-IDS_CIC_MLP.joblib', 'SCAN_CIC-IDS_CIC_NB.joblib', 'SCAN_CIC-IDS_CIC_SVM.joblib', 'SCAN_CIC-IDS_CIC_XGB.joblib']
# DT's index of best performance: 4
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# XGB
# Found F1-score file for SCAN_CIC-IDS_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-12 16:36:06
# Evaluating SCAN_CIC-IDS_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-12 16:36:17
# F1-score for DT: 0.0
#
# LR's score = 0.0
# 2022-01-12 16:36:26
# F1-score for LR: 0.0
#
# MLP's score = 0.0
# ...

# %% [markdown]
# ## Test CIC-ToN-IoT data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 3 $TYPE_OF_TEST
# Out:
# ToN-IoT and BoT-IoT only available in CIC dataset type
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_ToN-IoT_CIC
# Models fetched: ['SCAN_ToN-IoT_CIC_DT.joblib', 'SCAN_ToN-IoT_CIC_LR.joblib', 'SCAN_ToN-IoT_CIC_MLP.joblib', 'SCAN_ToN-IoT_CIC_NB.joblib', 'SCAN_ToN-IoT_CIC_SVM.joblib', 'SCAN_ToN-IoT_CIC_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# XGB
# Found F1-score file for SCAN_ToN-IoT_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-10 13:03:10
# Evaluating SCAN_ToN-IoT_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-10 13:03:21
# F1-score for DT: 0.0
#
# LR's score = 0.0
# ...

# %% [markdown]
# ## Test CIC-BoT-IoT data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 4 $TYPE_OF_TEST
# Out:
# ToN-IoT and BoT-IoT only available in CIC dataset type
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_BoT-IoT_CIC
# Models fetched: ['SCAN_BoT-IoT_CIC_DT.joblib', 'SCAN_BoT-IoT_CIC_LR.joblib', 'SCAN_BoT-IoT_CIC_MLP.joblib', 'SCAN_BoT-IoT_CIC_NB.joblib', 'SCAN_BoT-IoT_CIC_SVM.joblib', 'SCAN_BoT-IoT_CIC_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# XGB
# Found F1-score file for SCAN_BoT-IoT_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-12 17:16:21
# Evaluating SCAN_BoT-IoT_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-12 17:16:32
# F1-score for DT: 0.0
#
# LR's score = 0.0
# ...

# %% [markdown]
# ## Test internet AB-TRAP data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 5 $TYPE_OF_TEST
# Out:
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_internet_CIC
# Models fetched: ['SCAN_internet_CIC_DT.joblib', 'SCAN_internet_CIC_LR.joblib', 'SCAN_internet_CIC_MLP.joblib', 'SCAN_internet_CIC_NB.joblib', 'SCAN_internet_CIC_SVM.joblib', 'SCAN_internet_CIC_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# DT
# Found F1-score file for SCAN_internet_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-10 12:18:19
# Evaluating SCAN_internet_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-10 12:18:30
# F1-score for DT: 0.0
#
# LR's score = 0.0
# 2022-01-10 12:18:40
# F1-score for LR: 0.0
#
# MLP's score = 0.0
# ...
